# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Automobile_data.csv")

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
df.replace("?",np.nan,inplace=True)

# %%
df[df["num-of-doors"].isnull()].index.tolist()
# Out:
# [27, 63]

# %%
df["num-of-doors"][27]=np.nan
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_2968\840587816.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["num-of-doors"][27]=np.nan

# %%
type(df["num-of-doors"][27])
# Out:
# float

# %%
df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
pd.options.display.max_columns=None

# %%
df["normalized-losses"].median()
# Out:
# 115.0

# %%
df["normalized-losses"].fillna(df['normalized-losses'].median(),inplace=True)

# %%
df['normalized-losses']=df['normalized-losses'].astype(int)

# %%
df
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                115  alfa-romero       gas        std
# 1            3                115  alfa-romero       gas        std
# 2            1                115  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 200         -1                 95        volvo       gas        std
# 201         -1                 95        volvo       gas      turbo
# 202         -1                 95        volvo       gas        std
# 203         -1                 95        volvo    diesel      turbo
# 204         -1                 95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# ...

# %%
d=df[df['body-style']=="sedan"]
d['num-of-doors'].value_counts()
# Out:
# four    79
# two     15
# Name: num-of-doors, dtype: int64

# %%
df['num-of-doors']=df['num-of-doors'].replace({"four":4,"two":2,np.nan:0})

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 4
# stroke               4
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 4
# stroke               4
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
df["num-of-doors"].unique()
# Out:
# array([2., 4., 0.])

# %%
df["bore"]=df["bore"].replace({np.nan:0})
df['stroke']=df["stroke"].replace({np.nan:0})

# %%
pd.options.display.max_rows=None

# %%
df[["normalized-losses","num-of-doors","aspiration"]]
pd.options.display.max_rows=10

# %%
df[df['num-of-doors']==4][["num-of-doors",'aspiration']]
# Out:
#      num-of-doors aspiration
# 3             4.0        std
# 4             4.0        std
# 6             4.0        std
# 7             4.0        std
# 8             4.0      turbo
# ..            ...        ...
# 200           4.0        std
# 201           4.0      turbo
# 202           4.0        std
# 203           4.0      turbo
# 204           4.0      turbo
#
# [114 rows x 2 columns]

# %%
std=df[(df['num-of-doors']==4)&(df['aspiration']=="std")]
std['normalized-losses'].value_counts()
# Out:
# 115    19
# 91      8
# 103     4
# 94      4
# 65      4
#        ..
# 78      1
# 77      1
# 188     1
# 90      1
# 192     1
# Name: normalized-losses, Length: 32, dtype: int64

# %%
df[df['num-of-doors']==0]
# Out:
#     symboling  normalized-losses   make fuel-type aspiration  num-of-doors  \
# 27          1                148  dodge       gas      turbo           0.0
# 63          0                115  mazda    diesel        std           0.0
#
#    body-style drive-wheels engine-location  wheel-base  length  width  height  \
# 27      sedan          fwd           front        93.7   157.3   63.8    50.6
# 63      sedan          fwd           front        98.8   177.8   66.5    55.5
#
#     curb-weight engine-type num-of-cylinders  engine-size fuel-system  bore  \
# 27         2191         ohc             four           98        mpfi  3.03
# 63         2443         ohc             four          122         idi  3.39
#
#    stroke  compression-ratio horsepower peak-rpm  city-mpg  highway-mpg  price
# 27   3.39                7.6        102     5500        24           30   8558
# 63   3.39               22.7         64     4650        36           42  10795

# %%
df[df["normalized-losses"]==148]
# Out:
#     symboling  normalized-losses   make fuel-type aspiration  num-of-doors  \
# 24          1                148  dodge       gas        std           4.0
# 25          1                148  dodge       gas        std           4.0
# 26          1                148  dodge       gas        std           4.0
# 27          1                148  dodge       gas      turbo           0.0
#
#    body-style drive-wheels engine-location  wheel-base  length  width  height  \
# 24  hatchback          fwd           front        93.7   157.3   63.8    50.6
# 25      sedan          fwd           front        93.7   157.3   63.8    50.6
# 26      sedan          fwd           front        93.7   157.3   63.8    50.6
# 27      sedan          fwd           front        93.7   157.3   63.8    50.6
#
#     curb-weight engine-type num-of-cylinders  engine-size fuel-system  bore  \
# 24         1967         ohc             four           90        2bbl  2.97
# ...

# %%
df['num-of-doors']
# Out:
# 0      2.0
# 1      2.0
# 2      2.0
# 3      4.0
# 4      4.0
#       ...
# 200    4.0
# 201    4.0
# 202    4.0
# 203    4.0
# 204    4.0
# Name: num-of-doors, Length: 205, dtype: float64

# %%
df[(df["normalized-losses"]==115)&(df['fuel-type']=="diesel")]
# Out:
#      symboling  normalized-losses        make fuel-type aspiration  \
# 63           0                115       mazda    diesel        std
# 66           0                115       mazda    diesel        std
# 110          0                115      peugot    diesel      turbo
# 114          0                115      peugot    diesel      turbo
# 192          0                115  volkswagen    diesel      turbo
#
#      num-of-doors body-style drive-wheels engine-location  wheel-base  length  \
# 63            0.0      sedan          fwd           front        98.8   177.8
# 66            4.0      sedan          rwd           front       104.9   175.0
# 110           4.0      wagon          rwd           front       114.2   198.9
# 114           4.0      wagon          rwd           front       114.2   198.9
# 192           4.0      sedan          fwd           front       100.4   180.2
#
#      width  height  curb-weight engine-type num-of-cylinders  engine-size  \
# ...

# %%
df['num-of-doors']=df['num-of-doors'].replace({0:4})

# %%
df["num-of-doors"]=df["num-of-doors"].astype(int)

# %%
df["bore"].replace(np.nan,0)
df["stroke"].replace(np.nan,0)
# Out:
# 0      2.68
# 1      2.68
# 2      3.47
# 3       3.4
# 4       3.4
#        ...
# 200    3.15
# 201    3.15
# 202    2.87
# 203     3.4
# 204    3.15
# Name: stroke, Length: 205, dtype: object

# %%
df['num-of-cylinders']=df['num-of-cylinders'].replace({"four":4,"five":5,"six":6,"eight":8,"two":2,"three":3,"twelve":11})

# %%
df['num-of-cylinders'].value_counts()
# Out:
# 4     159
# 6      24
# 5      11
# 8       5
# 2       4
# 3       1
# 11      1
# Name: num-of-cylinders, dtype: int64

# %%
import math as ma

# %%
(ma.pi/4)*3.47**2*2.68*4
# Out:
# 101.37797599339304

# %%
3.47**2
# Out:
# 12.0409

# %%
df['bore']=df['bore'].astype(float)
df['stroke']=df['stroke'].astype(float)
df['num-of-cylinders']=df['num-of-cylinders'].astype(float)

# %%
Ser=df["bore"]
Ser_5=df["bore"].pow(2,level=2,axis=0,fill_value=0)

# %%
Ser_1=df['stroke']
Ser_1
# Out:
# 0      2.68
# 1      2.68
# 2      3.47
# 3      3.40
# 4      3.40
#        ...
# 200    3.15
# 201    3.15
# 202    2.87
# 203    3.40
# 204    3.15
# Name: stroke, Length: 205, dtype: float64

# %%
Ser_3=df['num-of-cylinders']
91.53562
# Out:
# 91.53562

# %%
df["Displacement_cu.in."]=(ma.pi/4)*Ser_5*Ser_1*Ser_3

# %%
df[df['Displacement_cu.in.']==0]
# Out:
#     symboling  normalized-losses   make fuel-type aspiration  num-of-doors  \
# 55          3                150  mazda       gas        std             2
# 56          3                150  mazda       gas        std             2
# 57          3                150  mazda       gas        std             2
# 58          3                150  mazda       gas        std             2
#
#    body-style drive-wheels engine-location  wheel-base  length  width  height  \
# 55  hatchback          rwd           front        95.3   169.0   65.7    49.6
# 56  hatchback          rwd           front        95.3   169.0   65.7    49.6
# 57  hatchback          rwd           front        95.3   169.0   65.7    49.6
# 58  hatchback          rwd           front        95.3   169.0   65.7    49.6
#
#     curb-weight engine-type  num-of-cylinders  engine-size fuel-system  bore  \
# 55         2380       rotor               2.0           70        4bbl   0.0
# ...

# %%
91.53562
# Out:
# 91.53562

# %%
df
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                115  alfa-romero       gas        std
# 1            3                115  alfa-romero       gas        std
# 2            1                115  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 200         -1                 95        volvo       gas        std
# 201         -1                 95        volvo       gas      turbo
# 202         -1                 95        volvo       gas        std
# 203         -1                 95        volvo    diesel      turbo
# 204         -1                 95        volvo       gas      turbo
#
#      num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0               2  convertible          rwd           front        88.6
# ...

# %%
df['bore']=df["bore"].replace({0:2.23 })

# %%
Ser=df[df['Displacement_cu.in.']==0]["Displacement_cu.in."].index

# %%
df.loc[Ser,'Displacement_cu.in.']=91.53562

# %%
# S = 4D/(πB²N).
df[df["stroke"]==0]
# S=3.906
Ser=df[df['stroke']==0]["stroke"].index
df.loc[Ser,'Displacement_cu.in.']=3.906

# %%
# 1985 Mazda RX-7(SA)
# 1985

# %%
df["aspiration"].value_counts()
# Out:
# std      168
# turbo     37
# Name: aspiration, dtype: int64

# %%
df['stroke'].max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of 0      2.68
# 1      2.68
# 2      3.47
# 3      3.40
# 4      3.40
#        ...
# 200    3.15
# 201    3.15
# 202    2.87
# 203    3.40
# 204    3.15
# Name: stroke, Length: 205, dtype: float64>

# %%
df
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                115  alfa-romero       gas        std
# 1            3                115  alfa-romero       gas        std
# 2            1                115  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 200         -1                 95        volvo       gas        std
# 201         -1                 95        volvo       gas      turbo
# 202         -1                 95        volvo       gas        std
# 203         -1                 95        volvo    diesel      turbo
# 204         -1                 95        volvo       gas      turbo
#
#      num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0               2  convertible          rwd           front        88.6
# ...

# %%
X=df.drop("price",axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   symboling            205 non-null    int64
#  1   normalized-losses    205 non-null    int32
#  2   make                 205 non-null    object
#  3   fuel-type            205 non-null    object
#  4   aspiration           205 non-null    object
#  5   num-of-doors         205 non-null    int32
#  6   body-style           205 non-null    object
#  7   drive-wheels         205 non-null    object
#  8   engine-location      205 non-null    object
#  9   wheel-base           205 non-null    float64
#  10  length               205 non-null    float64
#  11  width                205 non-null    float64
#  12  height               205 non-null    float64
#  13  curb-weight          205 non-null    int64
#  14  engine-type          205 non-null    object
# ...

# %%
pd.options.display.max_rows=None
df.isnull().sum()
pd.options.display.max_rows=10

# %%
df[df["peak-rpm"].isnull().tolist()]
# Out:
#      symboling  normalized-losses     make fuel-type aspiration  num-of-doors  \
# 130          0                115  renault       gas        std             4
# 131          2                115  renault       gas        std             2
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 130      wagon          fwd           front        96.1   181.5   66.5
# 131  hatchback          fwd           front        96.1   176.8   66.6
#
#      height  curb-weight engine-type  num-of-cylinders  engine-size  \
# 130    55.2         2579         ohc               4.0          132
# 131    50.5         2460         ohc               4.0          132
#
#     fuel-system  bore  stroke  compression-ratio horsepower peak-rpm  \
# 130        mpfi  3.46     3.9                8.7        NaN      NaN
# 131        mpfi  3.46     3.9                8.7        NaN      NaN
#
#      city-mpg  highway-mpg price  Displacement_cu.in.
# ...

# %%
# 1985 Renault Sportwagon
df['horsepower']=df['horsepower'].astype(float)

# %%
df.loc[130,"horsepower"]=131.6

# %%
df[df["peak-rpm"].isnull().tolist()]
# Out:
#      symboling  normalized-losses     make fuel-type aspiration  num-of-doors  \
# 130          0                115  renault       gas        std             4
# 131          2                115  renault       gas        std             2
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 130      wagon          fwd           front        96.1   181.5   66.5
# 131  hatchback          fwd           front        96.1   176.8   66.6
#
#      height  curb-weight engine-type  num-of-cylinders  engine-size  \
# 130    55.2         2579         ohc               4.0          132
# 131    50.5         2460         ohc               4.0          132
#
#     fuel-system  bore  stroke  compression-ratio  horsepower peak-rpm  \
# 130        mpfi  3.46     3.9                8.7       131.6      NaN
# 131        mpfi  3.46     3.9                8.7         NaN      NaN
#
#      city-mpg  highway-mpg price  Displacement_cu.in.
# ...

# %%
# 1985 Renault Fuego 2.2 Litre Automatic
#  5,700

# %%
df.loc[131,"horsepower"]=131.6

# %%
df[df["peak-rpm"].isnull().tolist()]
# Out:
#      symboling  normalized-losses     make fuel-type aspiration  num-of-doors  \
# 130          0                115  renault       gas        std             4
# 131          2                115  renault       gas        std             2
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 130      wagon          fwd           front        96.1   181.5   66.5
# 131  hatchback          fwd           front        96.1   176.8   66.6
#
#      height  curb-weight engine-type  num-of-cylinders  engine-size  \
# 130    55.2         2579         ohc               4.0          132
# 131    50.5         2460         ohc               4.0          132
#
#     fuel-system  bore  stroke  compression-ratio  horsepower peak-rpm  \
# 130        mpfi  3.46     3.9                8.7       131.6      NaN
# 131        mpfi  3.46     3.9                8.7       131.6      NaN
#
#      city-mpg  highway-mpg price  Displacement_cu.in.
# ...

# %%
# the max rpm due 
df.loc[130,"peak-rpm"]=4700

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   symboling            205 non-null    int64
#  1   normalized-losses    205 non-null    int32
#  2   make                 205 non-null    object
#  3   fuel-type            205 non-null    object
#  4   aspiration           205 non-null    object
#  5   num-of-doors         205 non-null    int32
#  6   body-style           205 non-null    object
#  7   drive-wheels         205 non-null    object
#  8   engine-location      205 non-null    object
#  9   wheel-base           205 non-null    float64
#  10  length               205 non-null    float64
#  11  width                205 non-null    float64
#  12  height               205 non-null    float64
#  13  curb-weight          205 non-null    int64
#  14  engine-type          205 non-null    object
# ...

# %%
df["price"]=df["price"].astype(float)

# %%
df[df["price"].isnull().tolist()]
# Out:
#      symboling  normalized-losses     make fuel-type aspiration  num-of-doors  \
# 9            0                115     audi       gas      turbo             2
# 44           1                115    isuzu       gas        std             2
# 45           0                115    isuzu       gas        std             4
# 129          1                115  porsche       gas        std             2
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 9    hatchback          4wd           front        99.5   178.2   67.9
# 44       sedan          fwd           front        94.5   155.9   63.6
# 45       sedan          fwd           front        94.5   155.9   63.6
# 129  hatchback          rwd           front        98.4   175.7   72.3
#
#      height  curb-weight engine-type  num-of-cylinders  engine-size  \
# 9      52.0         3053         ohc               5.0          131
# 44     52.0         1874         ohc               4.0           90
# ...

# %%
df.loc[9,"price"]=80000

# %%
df[df["price"].isnull().tolist()]
# Out:
#      symboling  normalized-losses     make fuel-type aspiration  num-of-doors  \
# 44           1                115    isuzu       gas        std             2
# 45           0                115    isuzu       gas        std             4
# 129          1                115  porsche       gas        std             2
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 44       sedan          fwd           front        94.5   155.9   63.6
# 45       sedan          fwd           front        94.5   155.9   63.6
# 129  hatchback          rwd           front        98.4   175.7   72.3
#
#      height  curb-weight engine-type  num-of-cylinders  engine-size  \
# 44     52.0         1874         ohc               4.0           90
# 45     52.0         1909         ohc               4.0           90
# 129    50.5         3366       dohcv               8.0          203
#
#     fuel-system  bore  stroke  compression-ratio  horsepower peak-rpm  \
# ...

# %%
pd.options.display.max_rows=None
gr=df.groupby(["make","normalized-losses","num-of-cylinders"])["price"]
gr.median()
# Out:
# make           normalized-losses  num-of-cylinders
# alfa-romero    115                4.0                 14997.5
#                                   6.0                 16500.0
# audi           115                5.0                 18920.0
#                158                5.0                 20792.5
#                164                4.0                 13950.0
#                                   5.0                 17450.0
# bmw            115                6.0                 33820.0
#                188                6.0                 21037.5
#                192                4.0                 16677.5
# chevrolet      81                 4.0                  6575.0
#                98                 4.0                  6295.0
#                121                3.0                  5151.0
# dodge          110                4.0                  8921.0
#                118                4.0                  6377.0
# ...

# %%
# The Holden Gemini 1985 prices range from $1,800 for the basic trim level Sedan Gemini SL/X to $3,630 for the top of the range Sedan Gemini SL/E.
# 1987 Isuzu Gemini 2nd-gen
df.loc[44,"price"]=1800
df.loc[45,"price"]=3630

# 1987 Isuzu Gemini 2nd-gen 2 doors $1800
# 1987 Isuzu Gemini 2nd-gen 4 doors $3630

# %%
df[df["price"].isnull().tolist()]
# Out:
#      symboling  normalized-losses     make fuel-type aspiration  num-of-doors  \
# 129          1                115  porsche       gas        std             2
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 129  hatchback          rwd           front        98.4   175.7   72.3
#
#      height  curb-weight engine-type  num-of-cylinders  engine-size  \
# 129    50.5         3366       dohcv               8.0          203
#
#     fuel-system  bore  stroke  compression-ratio  horsepower peak-rpm  \
# 129        mpfi  3.94    3.11               10.0       288.0     5750
#
#      city-mpg  highway-mpg  price  Displacement_cu.in.
# 129        17           28    NaN           303.342108

# %%
# 1985 Porsche 928 S (man. 5) 
# Autotrader has 19 Used Porsche 928s for sale, including a 1983 Porsche 928 S, a 1984 Porsche 928 S, and a 1985 Porsche 928 S ranging in price from $6,950 to $88,900.
df.loc[129,"price"]=40975

# %%
df["price"].min()
# 80000
# Out:
# 40.975

# %%
y=df["price"]

# %%
df.drop("peak-rpm",axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# symboling              0
# normalized-losses      0
# make                   0
# fuel-type              0
# aspiration             0
# num-of-doors           0
# body-style             0
# drive-wheels           0
# engine-location        0
# wheel-base             0
# length                 0
# width                  0
# height                 0
# curb-weight            0
# engine-type            0
# num-of-cylinders       0
# engine-size            0
# fuel-system            0
# bore                   0
# stroke                 0
# compression-ratio      0
# horsepower             0
# city-mpg               0
# highway-mpg            0
# price                  0
# Displacement_cu.in.    0
# dtype: int64
